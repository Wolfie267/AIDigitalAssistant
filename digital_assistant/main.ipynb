# %% [markdown]
# <hr>

# %% [markdown]
# # &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; **AI Digital Assistant Program**

# %% [markdown]
# <hr>

# %% [markdown]
# ![title](files/images/Jarvis.png)

# %% [markdown]
# <hr>

# %% [markdown]
# > <h1>Abilities</h1>
# <br>
#
# <ol>
# <h4><li>Artificial Intelligence Chatbot</li></h4>
# <h4><li>Object Detection</li></h4>
# <h4><li>Face Detection</li></h4>
# <h4><li>Product Recommendation</li></h4>
# <h4><li>Fake News Detection</li></h4>
# <h4><li>Pneumonia Prediction</li></h4>
# <h4><li>Covid Prediction</li></h4>
# <h4><li>Handwritten Digits Recognition</li></h4>
# </ol>
# <br>

# %% [markdown]
# <hr>

# %% [markdown]
# > <h1>Add-On Capabilities</h1>
# <br>
#
# <ol>
# <h4><li>Voice Command Input</li></h4>
# <h4><li>Audio + Text Feedback</li></h4>
# <h4><li>Device Controlling</li></h4>
# </ol>
# <br>

# %% [markdown]
# <hr>

# %% [markdown]
# ## 1. Neccessary Imports

# %%
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
from warnings import filterwarnings as fw
fw('ignore')

# %% [markdown]
# ## 2. Opening Intents.json file and loading it

# %%
File = open('files/intents.json')
data = json.load(File)

# %% [markdown]
# ## 3. Create Word Net Lemmatizer

# %%
lemmatizer = WordNetLemmatizer()                                    # Initializing lemmatizer to get 'stem' of words
words, classes, doc_X, doc_Y = [], [], [], []                       # Some declarations

# %% [markdown]
# ## 4. Iterate Intents and extract essentials

# %%
for intent in data['intents']:                                      # loop through all the intents
    for pattern in intent['text']:                                  # tokenize each pattern and append tokens to words
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_Y.append(intent['intent'])
    
    if intent['intent'] not in classes:
        classes.append(intent['intent'])                            # add the intent to the classes

# Removes punctuation, lowercase string, lemmatize words
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]

# Sort the words and classes in alpha order and ensure no duplicates
words, classes = sorted(set(words)), sorted(set(classes))

# %% [markdown]
# ## 5. Exploratory Data Analysis

# %%
print(words, classes, doc_X, doc_Y, sep='\n\n')
# Out:
# ["'s", 'a', 'about', 'adam', 'adios', 'am', 'any', 'anyone', 'are', 'arijit', 'aware', 'bay', 'be', 'bella', 'bored', 'by', 'bye', 'call', 'camera', 'can', 'cheering', 'clever', 'communicating', 'comprendo', 'conscious', 'could', 'creator', 'do', 'doing', 'door', 'enough', 'for', 'friend', 'fuck', 'genious', 'get', 'girl', 'give', 'god', 'good', 'goodbye', 'gossip', 'got', 'great', 'hang', 'have', 'hear', 'hello', 'help', 'helpful', 'heya', 'hi', 'himanshu', 'hola', 'hope', 'how', 'hya', 'i', 'identify', 'in', 'intelligent', 'is', 'it', 'joke', 'karan', 'know', 'later', 'laugh', 'make', 'me', 'mean', 'meant', 'more', 'my', "n't", 'name', 'need', 'not', 'off', 'ok', 'open', 'out', 'plan', 'please', 'pod', 'prove', 'quiet', 'rashi', 'real', 'saying', 'see', 'self', 'self-aware', 'shhh', 'shit', 'shut', 'some', 'speaking', 'stop', 'surely', 'talking', 'tell', 'thank', 'thanks', 'that', 'the', 'there', 'think', 'this', 'time', 'to', 'twat', 'understand', 'up', 'user', 'very', 'wa', 'want', 'week', 'weekend', 'well', 'what', 'who', 'why', 'will', 'with', 'you', 'your']
#
# ['Clever', 'CourtesyGoodBye', 'CourtesyGreeting', 'CourtesyGreetingResponse', 'Creator', 'CurrentHumanQuery', 'GoodBye', 'Gossip', 'Greeting', 'GreetingResponse', 'Jokes', 'NameQuery', 'NotTalking2U', 'PodBayDoor', 'PodBayDoorResponse', 'RealNameQuery', 'SelfAware', 'Shutup', 'Swearing', 'Thanks', 'TimeQuery', 'UnderstandQuery', 'WhoAmI', 'date']
#
# ['Hi', 'Hi there', 'Hola', 'Hello', 'Hello there', 'Heya', 'Hya there', 'what are you doing this weekend?', 'do you want to hang out some time?', 'what are your plans for this week', 'My user is Himanshu', 'This is Himanshu', 'I am Himanshu', 'It is Adam', 'My user is Bella', 'This is Rashi', 'I am Arijit', 'It is Karan', 'How are you?', 'Hi how are you?', 'Hello how are you?', 'Hola how are you?', 'How are you doing?', 'Hope you are doing well?', 'Hello hope you are doing well?', 'Good thanks! My user is Himanshu', 'Good thanks! This is Adam', 'Good thanks! I am Himanshu', 'Good thanks! It is Arijit', 'Great thanks! My user is Bella', 'Great thanks! This is Karan', 'Great thanks! I am Rashi', 'Great thanks! It is Himanshu', 'What is my name?', 'What do you call me?', 'Who do you think I am?', 'What do you think I am?', 'Who are you talking to?', 'What name do you call me by?', 'Tell me my name', 'What is your name?', 'What could I call you?', 'What can I call you?', 'What do your friends call you?', 'Who are you?', 'Tell me your name?', 'What is your real name?', 'What is your real name please?', "What's your real name?", 'Tell me your real name?', 'Your real name?', 'Your real name please?', 'Your real name please?', 'What is the time?', "What's the time?", 'Do you know what time it is?', 'Do you know the time?', 'Can you tell me the time?', 'Tell me what time it is?', 'Time', 'OK thank you', 'OK thanks', 'OK', 'Thanks', 'Thank you', "That's helpful", 'I am not talking to you', 'I was not talking to you', 'Not talking to you', "Wasn't for you", "Wasn't meant for you", "Wasn't communicating to you", "Wasn't speaking to you", 'Do you understand what I am saying', 'Do you understand me', 'Do you know what I am saying', 'Do you get me', 'Comprendo', 'Know what I mean', 'Be quiet', 'Shut up', 'Stop talking', 'Enough talking', 'Please be quiet', 'Quiet', 'Shhh', 'fuck off', 'fuck', 'twat', 'shit', 'Bye', 'Adios', 'See you later', 'Goodbye', 'Thanks, bye', 'Thanks for the help, goodbye', 'Thank you, bye', 'Thank you, goodbye', 'Thanks goodbye', 'Thanks good bye', 'Can you see me?', 'Do you see me?', 'Can you see anyone in the camera?', 'Do you see anyone in the camera?', 'Identify me', 'Who am I please', 'You are very clever', 'You are a very clever girl', 'You are very intelligent', 'You are a very intelligent girl', 'You are a genious', 'Clever girl', 'Genious', 'I am bored gossip with me', 'Got any gossip', 'I want to hear some gossip', 'Tell me some gossip', 'Any gossip', 'Tell me some more gossip', 'Tell me a joke', 'Do you know any jokes', 'How about a joke', 'Give me a joke', 'Make me laugh', 'I need cheering up', 'Open the pod bay door', 'Can you open the pod bay door', 'Will you open the pod bay door', 'Open the pod bay door please', 'Can you open the pod bay door please', 'Will you open the pod bay door please', 'Pod bay door', 'Why', 'Why not', 'Why can you not open the pod bay door', 'Why will you not open the pod bay door', 'Well why not', 'Surely you can', 'Tell me why', "Who's your Creator", "Who's your god", 'Can you prove you are self-aware', 'Can you prove you have a conscious', 'Can you prove you are self aware please', 'Can you prove you have a conscious please', 'prove you have a conscious']
#
# ['Greeting', 'Greeting', 'Greeting', 'Greeting', 'Greeting', 'Greeting', 'Greeting', 'date', 'date', 'date', 'GreetingResponse', 'GreetingResponse', 'GreetingResponse', 'GreetingResponse', 'GreetingResponse', 'GreetingResponse', 'GreetingResponse', 'GreetingResponse', 'CourtesyGreeting', 'CourtesyGreeting', 'CourtesyGreeting', 'CourtesyGreeting', 'CourtesyGreeting', 'CourtesyGreeting', 'CourtesyGreeting', 'CourtesyGreetingResponse', 'CourtesyGreetingResponse', 'CourtesyGreetingResponse', 'CourtesyGreetingResponse', 'CourtesyGreetingResponse', 'CourtesyGreetingResponse', 'CourtesyGreetingResponse', 'CourtesyGreetingResponse', 'CurrentHumanQuery', 'CurrentHumanQuery', 'CurrentHumanQuery', 'CurrentHumanQuery', 'CurrentHumanQuery', 'CurrentHumanQuery', 'CurrentHumanQuery', 'NameQuery', 'NameQuery', 'NameQuery', 'NameQuery', 'NameQuery', 'NameQuery', 'RealNameQuery', 'RealNameQuery', 'RealNameQuery', 'RealNameQuery', 'RealNameQuery', 'RealNameQuery', 'RealNameQuery', 'TimeQuery', 'TimeQuery', 'TimeQuery', 'TimeQuery', 'TimeQuery', 'TimeQuery', 'TimeQuery', 'Thanks', 'Thanks', 'Thanks', 'Thanks', 'Thanks', 'Thanks', 'NotTalking2U', 'NotTalking2U', 'NotTalking2U', 'NotTalking2U', 'NotTalking2U', 'NotTalking2U', 'NotTalking2U', 'UnderstandQuery', 'UnderstandQuery', 'UnderstandQuery', 'UnderstandQuery', 'UnderstandQuery', 'UnderstandQuery', 'Shutup', 'Shutup', 'Shutup', 'Shutup', 'Shutup', 'Shutup', 'Shutup', 'Swearing', 'Swearing', 'Swearing', 'Swearing', 'GoodBye', 'GoodBye', 'GoodBye', 'GoodBye', 'CourtesyGoodBye', 'CourtesyGoodBye', 'CourtesyGoodBye', 'CourtesyGoodBye', 'CourtesyGoodBye', 'CourtesyGoodBye', 'WhoAmI', 'WhoAmI', 'WhoAmI', 'WhoAmI', 'WhoAmI', 'WhoAmI', 'Clever', 'Clever', 'Clever', 'Clever', 'Clever', 'Clever', 'Clever', 'Gossip', 'Gossip', 'Gossip', 'Gossip', 'Gossip', 'Gossip', 'Jokes', 'Jokes', 'Jokes', 'Jokes', 'Jokes', 'Jokes', 'PodBayDoor', 'PodBayDoor', 'PodBayDoor', 'PodBayDoor', 'PodBayDoor', 'PodBayDoor', 'PodBayDoor', 'PodBayDoorResponse', 'PodBayDoorResponse', 'PodBayDoorResponse', 'PodBayDoorResponse', 'PodBayDoorResponse', 'PodBayDoorResponse', 'PodBayDoorResponse', 'Creator', 'Creator', 'SelfAware', 'SelfAware', 'SelfAware', 'SelfAware', 'SelfAware']

# %% [markdown]
# ## 6. Picklizing Lists for later use

# %%
import pickle
# Use Inspect functions
def Picklize(Object:list, fileName:str):
    with open(f'files/pickleFiles/{fileName}', 'wb') as fp: pickle.dump(Object, fp)

Picklize(words, 'words')
Picklize(classes, 'classes')
Picklize(data, 'data')

# %% [markdown]
# <hr>

# %% [markdown]
# ## 7. Refactor data and Extract Training Dataset

# %%
training = []
out_empty = [0] * len(classes)

# Creating Words model
for idx, doc in enumerate(doc_X):
    boWords = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        boWords.append(1) if word in text else boWords.append(0)
    
    output_row = list(out_empty)                        # mark the index of class that the current pattern is associated to
    output_row[classes.index(doc_Y[idx])] = 1
    training.append([boWords, output_row])              # add the one hot encoded boWords and associated classes to training 
    

random.shuffle(training)                                # Shuffle the data
training = np.array(training, dtype=object)             # Convert it to an array

# Split the features and target labels
train_X = np.array(list(training[:, 0]))
train_Y = np.array(list(training[:, 1]))

# %% [markdown]
# ## 8. Creation of Neural Networks

# %%
# Some Declarations
input_shape, output_shape = (len(train_X[0]),), len(train_Y[0])

# Addind layers to the neural networks model
model = Sequential()                                                # Creating Sequential model
model.add(Dense(128, input_shape=input_shape, activation="relu"))   # Adding Dense layer
model.add(Dropout(0.5))                                             # Adding Dropout layer
model.add(Dense(64, activation="relu"))                             # Adding Dense layer
model.add(Dropout(0.3))                                             # Adding Dropout layer
model.add(Dense(output_shape, activation = "softmax"))              # Adding Dense layer

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate = 0.01, decay = 1e-6), metrics=["accuracy"])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                1560
# =================================================================
# Total params: 26,328
# Trainable params: 26,328
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## 9. Training the Model

# %%
model.fit(x = train_X, y = train_Y, epochs = 1000, verbose = 1)
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 1s 3ms/step - loss: 3.1314 - accuracy: 0.0753
# Epoch 2/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 2.7133 - accuracy: 0.3014
# Epoch 3/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 2.3462 - accuracy: 0.3493
# Epoch 4/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.8480 - accuracy: 0.5137
# Epoch 5/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.5010 - accuracy: 0.6096
# Epoch 6/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1395 - accuracy: 0.7055
# Epoch 7/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0156 - accuracy: 0.6781
# Epoch 8/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8743 - accuracy: 0.7603
# Epoch 9/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6641 - accuracy: 0.8356
# Epoch 10/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5760 - accuracy: 0.8493
# Epoch 11/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5057 - accuracy: 0.8356
# Epoch 12/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3514 - accuracy: 0.8973
# Epoch 13/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3277 - accuracy: 0.9110
# Epoch 14/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2557 - accuracy: 0.9315
# Epoch 15/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2061 - accuracy: 0.9452
# Epoch 16/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2086 - accuracy: 0.9384
# Epoch 17/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2584 - accuracy: 0.9315
# Epoch 18/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1807 - accuracy: 0.9452
# Epoch 19/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1959 - accuracy: 0.9452
# Epoch 20/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1323 - accuracy: 0.9589
# Epoch 21/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1420 - accuracy: 0.9795
# Epoch 22/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1895 - accuracy: 0.9315
# Epoch 23/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1554 - accuracy: 0.9658
# Epoch 24/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1435 - accuracy: 0.9521
# Epoch 25/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1974 - accuracy: 0.9452
# Epoch 26/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.9726
# Epoch 27/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.9795
# Epoch 28/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1139 - accuracy: 0.9658
# Epoch 29/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0691 - accuracy: 0.9795
# Epoch 30/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0561 - accuracy: 0.9795
# Epoch 31/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0614 - accuracy: 0.9795
# Epoch 32/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0971 - accuracy: 0.9658
# Epoch 33/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 0.9863
# Epoch 34/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0489 - accuracy: 0.9863
# Epoch 35/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0567 - accuracy: 0.9863
# Epoch 36/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 0.9795
# Epoch 37/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 38/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0815 - accuracy: 0.9589
# Epoch 39/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1112 - accuracy: 0.9726
# Epoch 40/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1111 - accuracy: 0.9726
# Epoch 41/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0503 - accuracy: 0.9795
# Epoch 42/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1240 - accuracy: 0.9589
# Epoch 43/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9932
# Epoch 44/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0991 - accuracy: 0.9795
# Epoch 45/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9863
# Epoch 46/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.9589
# Epoch 47/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0489 - accuracy: 0.9932
# Epoch 48/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 49/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0539 - accuracy: 0.9863
# Epoch 50/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 51/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 0.9726
# Epoch 52/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 53/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0524 - accuracy: 0.9795
# Epoch 54/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 55/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 0.9795
# Epoch 56/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 57/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 0.9932
# Epoch 58/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 59/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9726
# Epoch 60/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0741 - accuracy: 0.9726
# Epoch 61/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9932
# Epoch 62/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 0.9932
# Epoch 63/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0644 - accuracy: 0.9726
# Epoch 64/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9932
# Epoch 65/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 66/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0514 - accuracy: 0.9863
# Epoch 67/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 0.9863
# Epoch 68/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0407 - accuracy: 0.9863
# Epoch 69/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0464 - accuracy: 0.9726
# Epoch 70/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9726
# Epoch 71/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0382 - accuracy: 0.9863
# Epoch 72/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 0.9932
# Epoch 73/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9795
# Epoch 74/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9795
# Epoch 75/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 0.9795
# Epoch 76/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9863
# Epoch 77/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9863
# Epoch 78/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9932
# Epoch 79/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 0.9863
# Epoch 80/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 0.9863
# Epoch 81/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.9932
# Epoch 82/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0911 - accuracy: 0.9726
# Epoch 83/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9863
# Epoch 84/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0589 - accuracy: 0.9795
# Epoch 85/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 0.9932
# Epoch 86/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9863
# Epoch 87/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9863
# Epoch 88/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 0.9932
# Epoch 89/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 0.9863
# Epoch 90/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 0.9863
# Epoch 91/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0382 - accuracy: 0.9863
# Epoch 92/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 0.9932
# Epoch 93/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9795
# Epoch 94/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9795
# Epoch 95/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9932
# Epoch 96/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0661 - accuracy: 0.9658
# Epoch 97/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0593 - accuracy: 0.9932
# Epoch 98/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 0.9726
# Epoch 99/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 100/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0445 - accuracy: 0.9863
# Epoch 101/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.9863
# Epoch 102/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9932
# Epoch 103/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 0.9863
# Epoch 104/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1645 - accuracy: 0.9589
# Epoch 105/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9863
# Epoch 106/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.9932
# Epoch 107/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1355 - accuracy: 0.9658
# Epoch 108/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 0.9726
# Epoch 109/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 110/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9863
# Epoch 111/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0621 - accuracy: 0.9932
# Epoch 112/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 113/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0609 - accuracy: 0.9795
# Epoch 114/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 115/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0860 - accuracy: 0.9726
# Epoch 116/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 0.9932
# Epoch 117/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0764 - accuracy: 0.9795
# Epoch 118/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 119/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 0.9932
# Epoch 120/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0548 - accuracy: 0.9726
# Epoch 121/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0519 - accuracy: 0.9863
# Epoch 122/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0690 - accuracy: 0.9726
# Epoch 123/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0533 - accuracy: 0.9795
# Epoch 124/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9795
# Epoch 125/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 0.9795
# Epoch 126/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9932
# Epoch 127/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9795
# Epoch 128/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0985 - accuracy: 0.9863
# Epoch 129/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 0.9932
# Epoch 130/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.9589
# Epoch 131/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 0.9932
# Epoch 132/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 133/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0659 - accuracy: 0.9726
# Epoch 134/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 0.9863
# Epoch 135/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0949 - accuracy: 0.9726
# Epoch 136/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0976 - accuracy: 0.9726
# Epoch 137/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0464 - accuracy: 0.9932
# Epoch 138/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0522 - accuracy: 0.9863
# Epoch 139/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1084 - accuracy: 0.9658
# Epoch 140/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0918 - accuracy: 0.9795
# Epoch 141/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0885 - accuracy: 0.9726
# Epoch 142/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0644 - accuracy: 0.9795
# Epoch 143/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1267 - accuracy: 0.9658
# Epoch 144/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9726
# Epoch 145/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2083 - accuracy: 0.9452
# Epoch 146/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0635 - accuracy: 0.9658
# Epoch 147/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1154 - accuracy: 0.9521
# Epoch 148/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 149/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0395 - accuracy: 0.9863
# Epoch 150/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2148 - accuracy: 0.9589
# Epoch 151/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9658
# Epoch 152/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9932
# Epoch 153/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0989 - accuracy: 0.9658
# Epoch 154/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0682 - accuracy: 0.9863
# Epoch 155/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9795
# Epoch 156/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 157/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 0.9795
# Epoch 158/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9932
# Epoch 159/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1082 - accuracy: 0.9589
# Epoch 160/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0722 - accuracy: 0.9658
# Epoch 161/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0370 - accuracy: 0.9863
# Epoch 162/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 0.9863
# Epoch 163/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1382 - accuracy: 0.9589
# Epoch 164/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9932
# Epoch 165/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 0.9863
# Epoch 166/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 0.9726
# Epoch 167/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 0.9932
# Epoch 168/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9795
# Epoch 169/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0688 - accuracy: 0.9932
# Epoch 170/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9726
# Epoch 171/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0787 - accuracy: 0.9795
# Epoch 172/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 173/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1488 - accuracy: 0.9726
# Epoch 174/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 0.9863
# Epoch 175/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0892 - accuracy: 0.9863
# Epoch 176/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1285 - accuracy: 0.9726
# Epoch 177/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3912 - accuracy: 0.9658
# Epoch 178/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1641 - accuracy: 0.9726
# Epoch 179/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1365 - accuracy: 0.9589
# Epoch 180/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0915 - accuracy: 0.9658
# Epoch 181/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0121 - accuracy: 0.9932
# Epoch 182/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.9452
# Epoch 183/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0745 - accuracy: 0.9795
# Epoch 184/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3269 - accuracy: 0.9247
# Epoch 185/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2363 - accuracy: 0.9521
# Epoch 186/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.9658
# Epoch 187/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1727 - accuracy: 0.9658
# Epoch 188/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1321 - accuracy: 0.9726
# Epoch 189/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1568 - accuracy: 0.9658
# Epoch 190/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9795
# Epoch 191/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0511 - accuracy: 0.9726
# Epoch 192/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9932
# Epoch 193/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9795
# Epoch 194/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0684 - accuracy: 0.9863
# Epoch 195/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 0.9932
# Epoch 196/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1335 - accuracy: 0.9795
# Epoch 197/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9863
# Epoch 198/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 0.9932
# Epoch 199/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0260 - accuracy: 0.9863
# Epoch 200/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 201/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0856 - accuracy: 0.9795
# Epoch 202/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9932
# Epoch 203/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9795
# Epoch 204/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0575 - accuracy: 0.9863
# Epoch 205/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 206/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9932
# Epoch 207/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9726
# Epoch 208/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0452 - accuracy: 0.9863
# Epoch 209/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9589
# Epoch 210/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0398 - accuracy: 0.9795
# Epoch 211/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1070 - accuracy: 0.9658
# Epoch 212/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0659 - accuracy: 0.9795
# Epoch 213/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.9795
# Epoch 214/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0761 - accuracy: 0.9795
# Epoch 215/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9795
# Epoch 216/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1320 - accuracy: 0.9658
# Epoch 217/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9863
# Epoch 218/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0892 - accuracy: 0.9658
# Epoch 219/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9726
# Epoch 220/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9932
# Epoch 221/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0729 - accuracy: 0.9863
# Epoch 222/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 0.9795
# Epoch 223/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 224/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9726
# Epoch 225/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9932
# Epoch 226/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9932
# Epoch 227/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0533 - accuracy: 0.9795
# Epoch 228/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0773 - accuracy: 0.9726
# Epoch 229/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9795
# Epoch 230/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 0.9863
# Epoch 231/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9658
# Epoch 232/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2030 - accuracy: 0.9521
# Epoch 233/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 0.9863
# Epoch 234/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0508 - accuracy: 0.9863
# Epoch 235/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 236/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 0.9658
# Epoch 237/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 0.9795
# Epoch 238/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.9726
# Epoch 239/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 240/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9932
# Epoch 241/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0509 - accuracy: 0.9795
# Epoch 242/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9795
# Epoch 243/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1105 - accuracy: 0.9726
# Epoch 244/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.9658
# Epoch 245/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 0.9795
# Epoch 246/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9932
# Epoch 247/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1013 - accuracy: 0.9795
# Epoch 248/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 0.9863
# Epoch 249/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1312 - accuracy: 0.9726
# Epoch 250/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 0.9863
# Epoch 251/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0574 - accuracy: 0.9795
# Epoch 252/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 0.9932
# Epoch 253/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 0.9726
# Epoch 254/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9863
# Epoch 255/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0724 - accuracy: 0.9863
# Epoch 256/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0932 - accuracy: 0.9795
# Epoch 257/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0809 - accuracy: 0.9726
# Epoch 258/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0446 - accuracy: 0.9863
# Epoch 259/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2270 - accuracy: 0.9658
# Epoch 260/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9932
# Epoch 261/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 262/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0685 - accuracy: 0.9863
# Epoch 263/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1481 - accuracy: 0.9589
# Epoch 264/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0533 - accuracy: 0.9863
# Epoch 265/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 266/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 0.9795
# Epoch 267/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1176 - accuracy: 0.9726
# Epoch 268/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 0.9932
# Epoch 269/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9795
# Epoch 270/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 0.9932
# Epoch 271/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 272/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 273/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9863
# Epoch 274/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.9863
# Epoch 275/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 276/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9795
# Epoch 277/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 0.9863
# Epoch 278/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0838 - accuracy: 0.9863
# Epoch 279/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 0.9658
# Epoch 280/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 0.9932
# Epoch 281/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9932
# Epoch 282/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0517 - accuracy: 0.9863
# Epoch 283/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.9795
# Epoch 284/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9932
# Epoch 285/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 286/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9932
# Epoch 287/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1892 - accuracy: 0.9658
# Epoch 288/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0707 - accuracy: 0.9795
# Epoch 289/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9932
# Epoch 290/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 0.9932
# Epoch 291/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1079 - accuracy: 0.9795
# Epoch 292/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 0.9726
# Epoch 293/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1629 - accuracy: 0.9795
# Epoch 294/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9795
# Epoch 295/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0978 - accuracy: 0.9795
# Epoch 296/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1182 - accuracy: 0.9658
# Epoch 297/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1120 - accuracy: 0.9795
# Epoch 298/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 299/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0944 - accuracy: 0.9795
# Epoch 300/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 0.9795
# Epoch 301/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 0.9932
# Epoch 302/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.9795
# Epoch 303/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.9795
# Epoch 304/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1139 - accuracy: 0.9863
# Epoch 305/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1804 - accuracy: 0.9589
# Epoch 306/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0835 - accuracy: 0.9863
# Epoch 307/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 0.9863
# Epoch 308/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9726
# Epoch 309/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9932
# Epoch 310/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 0.9795
# Epoch 311/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9932
# Epoch 312/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 0.9795
# Epoch 313/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9795
# Epoch 314/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9726
# Epoch 315/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9932
# Epoch 316/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9863
# Epoch 317/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0729 - accuracy: 0.9863
# Epoch 318/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 319/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1972 - accuracy: 0.9521
# Epoch 320/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 0.9863
# Epoch 321/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0560 - accuracy: 0.9795
# Epoch 322/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1473 - accuracy: 0.9589
# Epoch 323/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0802 - accuracy: 0.9658
# Epoch 324/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9863
# Epoch 325/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9658
# Epoch 326/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 0.9932
# Epoch 327/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0733 - accuracy: 0.9932
# Epoch 328/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0896 - accuracy: 0.9863
# Epoch 329/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1284 - accuracy: 0.9795
# Epoch 330/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 0.9795
# Epoch 331/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1401 - accuracy: 0.9863
# Epoch 332/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0951 - accuracy: 0.9795
# Epoch 333/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 334/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0585 - accuracy: 0.9863
# Epoch 335/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 0.9863
# Epoch 336/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 337/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1660 - accuracy: 0.9795
# Epoch 338/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 339/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 0.9932
# Epoch 340/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 341/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 0.9726
# Epoch 342/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0748 - accuracy: 0.9795
# Epoch 343/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0547 - accuracy: 0.9726
# Epoch 344/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 0.9863
# Epoch 345/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0522 - accuracy: 0.9863
# Epoch 346/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0551 - accuracy: 0.9863
# Epoch 347/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0365 - accuracy: 0.9863
# Epoch 348/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.9795
# Epoch 349/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 0.9863
# Epoch 350/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0851 - accuracy: 0.9863
# Epoch 351/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 0.9932
# Epoch 352/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1277 - accuracy: 0.9795
# Epoch 353/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 354/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1256 - accuracy: 0.9726
# Epoch 355/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9932
# Epoch 356/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0460 - accuracy: 0.9795
# Epoch 357/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 0.9863
# Epoch 358/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0565 - accuracy: 0.9795
# Epoch 359/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 360/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 0.9932
# Epoch 361/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9932
# Epoch 362/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 0.9932
# Epoch 363/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 364/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 365/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 0.9863
# Epoch 366/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 0.9863
# Epoch 367/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 368/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9932
# Epoch 369/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1219 - accuracy: 0.9726
# Epoch 370/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9863
# Epoch 371/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9932
# Epoch 372/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 373/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 0.9863
# Epoch 374/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.9932
# Epoch 375/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 0.9932
# Epoch 376/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 0.9863
# Epoch 377/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 378/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9932
# Epoch 379/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0652 - accuracy: 0.9932
# Epoch 380/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 9.2471e-04 - accuracy: 1.0000
# Epoch 381/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0587 - accuracy: 0.9863
# Epoch 382/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9726
# Epoch 383/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0680 - accuracy: 0.9932
# Epoch 384/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0450 - accuracy: 0.9863
# Epoch 385/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1962 - accuracy: 0.9726
# Epoch 386/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9795
# Epoch 387/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0837 - accuracy: 0.9726
# Epoch 388/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 389/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 390/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1633 - accuracy: 0.9795
# Epoch 391/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9795
# Epoch 392/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1382 - accuracy: 0.9726
# Epoch 393/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.9932
# Epoch 394/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2000 - accuracy: 0.9658
# Epoch 395/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9932
# Epoch 396/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 397/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1424 - accuracy: 0.9863
# Epoch 398/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3054 - accuracy: 0.9521
# Epoch 399/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0930 - accuracy: 0.9863
# Epoch 400/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9795
# Epoch 401/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3197 - accuracy: 0.9726
# Epoch 402/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1071 - accuracy: 0.9726
# Epoch 403/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0611 - accuracy: 0.9658
# Epoch 404/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9863
# Epoch 405/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1419 - accuracy: 0.9863
# Epoch 406/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 407/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9932
# Epoch 408/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1292 - accuracy: 0.9795
# Epoch 409/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9932
# Epoch 410/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0579 - accuracy: 0.9863
# Epoch 411/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 412/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9932
# Epoch 413/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0622 - accuracy: 0.9726
# Epoch 414/1000
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0810 - accuracy: 0.9863
# Epoch 415/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0294 - accuracy: 0.9932
# Epoch 416/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9932
# Epoch 417/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1863 - accuracy: 0.9726
# Epoch 418/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9863
# Epoch 419/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 0.9863
# Epoch 420/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 421/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.9658
# Epoch 422/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 423/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9863
# Epoch 424/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1213 - accuracy: 0.9795
# Epoch 425/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0874 - accuracy: 0.9726
# Epoch 426/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0473 - accuracy: 0.9863
# Epoch 427/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9932
# Epoch 428/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9932
# Epoch 429/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9932
# Epoch 430/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1553 - accuracy: 0.9795
# Epoch 431/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0740 - accuracy: 0.9726
# Epoch 432/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9863
# Epoch 433/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1355 - accuracy: 0.9863
# Epoch 434/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0726 - accuracy: 0.9726
# Epoch 435/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9932
# Epoch 436/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.9452
# Epoch 437/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0478 - accuracy: 0.9863
# Epoch 438/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1425 - accuracy: 0.9658
# Epoch 439/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 0.9795
# Epoch 440/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 0.9726
# Epoch 441/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9863
# Epoch 442/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1542 - accuracy: 0.9863
# Epoch 443/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1438 - accuracy: 0.9726
# Epoch 444/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0747 - accuracy: 0.9726
# Epoch 445/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 0.9863
# Epoch 446/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0910 - accuracy: 0.9726
# Epoch 447/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9863
# Epoch 448/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3189 - accuracy: 0.9452
# Epoch 449/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2947 - accuracy: 0.9795
# Epoch 450/1000
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9932
# Epoch 451/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1728 - accuracy: 0.9726
# Epoch 452/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2957 - accuracy: 0.9795
# Epoch 453/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9932
# Epoch 454/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1358 - accuracy: 0.9795
# Epoch 455/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.9658
# Epoch 456/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1374 - accuracy: 0.9795
# Epoch 457/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 458/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9932
# Epoch 459/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 460/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.9726
# Epoch 461/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0413 - accuracy: 0.9932
# Epoch 462/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1628 - accuracy: 0.9795
# Epoch 463/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9932
# Epoch 464/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1605 - accuracy: 0.9795
# Epoch 465/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 466/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0535 - accuracy: 0.9863
# Epoch 467/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0908 - accuracy: 0.9863
# Epoch 468/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2329 - accuracy: 0.9658
# Epoch 469/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 0.9863
# Epoch 470/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0526 - accuracy: 0.9863
# Epoch 471/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 472/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1577 - accuracy: 0.9726
# Epoch 473/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1274 - accuracy: 0.9863
# Epoch 474/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 475/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 476/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9863
# Epoch 477/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0895 - accuracy: 0.9863
# Epoch 478/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 0.9932
# Epoch 479/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1709 - accuracy: 0.9863
# Epoch 480/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2648 - accuracy: 0.9863
# Epoch 481/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1023 - accuracy: 0.9658
# ...
# Epoch 842/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2555 - accuracy: 0.9932
# Epoch 843/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0405 - accuracy: 0.9795
# Epoch 844/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 845/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0482 - accuracy: 0.9932
# Epoch 846/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2778 - accuracy: 0.9795
# Epoch 847/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9932
# Epoch 848/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1129 - accuracy: 0.9795
# Epoch 849/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2682 - accuracy: 0.9726
# Epoch 850/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1155 - accuracy: 0.9932
# Epoch 851/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0285 - accuracy: 0.9932
# Epoch 852/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9932
# Epoch 853/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0628 - accuracy: 0.9795
# Epoch 854/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3191e-04 - accuracy: 1.0000
# Epoch 855/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 1.8115e-04 - accuracy: 1.0000
# Epoch 856/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 0.9863
# Epoch 857/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9932
# Epoch 858/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1355 - accuracy: 0.9863
# Epoch 859/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0815 - accuracy: 0.9863
# Epoch 860/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0849 - accuracy: 0.9932
# Epoch 861/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1636 - accuracy: 0.9795
# Epoch 862/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0492 - accuracy: 0.9863
# Epoch 863/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1695 - accuracy: 0.9863
# Epoch 864/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0290 - accuracy: 0.9863
# Epoch 865/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 0.9932
# Epoch 866/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0814 - accuracy: 0.9863
# Epoch 867/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0439 - accuracy: 0.9932
# Epoch 868/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2676 - accuracy: 0.9863
# Epoch 869/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 870/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0593 - accuracy: 0.9863
# Epoch 871/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 7.3952e-04 - accuracy: 1.0000
# Epoch 872/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0590 - accuracy: 0.9863
# Epoch 873/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1733 - accuracy: 0.9863
# Epoch 874/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1363 - accuracy: 0.9863
# Epoch 875/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 0.9932
# Epoch 876/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1016 - accuracy: 0.9726
# Epoch 877/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 0.9932
# Epoch 878/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 0.9932
# Epoch 879/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.9863
# Epoch 880/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1905 - accuracy: 0.9863
# Epoch 881/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9932
# Epoch 882/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1131 - accuracy: 0.9932
# Epoch 883/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9932
# Epoch 884/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0121 - accuracy: 0.9932
# Epoch 885/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9589
# Epoch 886/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 887/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0325 - accuracy: 0.9863
# Epoch 888/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 0.9932
# Epoch 889/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9863
# Epoch 890/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9932
# Epoch 891/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0619 - accuracy: 0.9795
# Epoch 892/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 893/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3264 - accuracy: 0.9795
# Epoch 894/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 895/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2101 - accuracy: 0.9932
# Epoch 896/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0620 - accuracy: 0.9863
# Epoch 897/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1745 - accuracy: 0.9863
# Epoch 898/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.9863
# Epoch 899/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1429 - accuracy: 0.9795
# Epoch 900/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 1.4825e-04 - accuracy: 1.0000
# Epoch 901/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0611 - accuracy: 0.9863
# Epoch 902/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9932
# Epoch 903/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 0.9932
# Epoch 904/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1175 - accuracy: 0.9863
# Epoch 905/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 0.9863
# Epoch 906/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9795
# Epoch 907/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0337 - accuracy: 0.9932
# Epoch 908/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9658
# Epoch 909/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 2.3237e-04 - accuracy: 1.0000
# Epoch 910/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2580 - accuracy: 0.9726
# Epoch 911/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.9795
# Epoch 912/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 913/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 914/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 0.9863
# Epoch 915/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3960 - accuracy: 0.9658
# Epoch 916/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 917/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0583 - accuracy: 0.9863
# Epoch 918/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 6.2271e-05 - accuracy: 1.0000
# Epoch 919/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9932
# Epoch 920/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1955 - accuracy: 0.9795
# Epoch 921/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0936 - accuracy: 0.9726
# Epoch 922/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2279 - accuracy: 0.9863
# Epoch 923/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1410 - accuracy: 0.9589
# Epoch 924/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 925/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2157 - accuracy: 0.9726
# Epoch 926/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.9726
# Epoch 927/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3027 - accuracy: 0.9795
# Epoch 928/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0717 - accuracy: 0.9932
# Epoch 929/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1123 - accuracy: 0.9863
# Epoch 930/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1577 - accuracy: 0.9795
# Epoch 931/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1304 - accuracy: 0.9726
# Epoch 932/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 0.9932
# Epoch 933/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1151 - accuracy: 0.9795
# Epoch 934/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 3.9861e-04 - accuracy: 1.0000
# Epoch 935/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9932
# Epoch 936/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9863
# Epoch 937/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 0.9932
# Epoch 938/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3272 - accuracy: 0.9726
# Epoch 939/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9863
# Epoch 940/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.9932
# Epoch 941/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2047 - accuracy: 0.9795
# Epoch 942/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9932
# Epoch 943/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 9.6944e-04 - accuracy: 1.0000
# Epoch 944/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9932
# Epoch 945/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 7.8204e-04 - accuracy: 1.0000
# Epoch 946/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9932
# Epoch 947/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9932
# Epoch 948/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9932
# Epoch 949/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0542 - accuracy: 0.9863
# Epoch 950/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9932
# Epoch 951/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1207 - accuracy: 0.9795
# Epoch 952/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 1.1398e-04 - accuracy: 1.0000
# Epoch 953/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0518 - accuracy: 0.9863
# Epoch 954/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 4.3558e-04 - accuracy: 1.0000
# Epoch 955/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 956/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 957/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 0.9932
# Epoch 958/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 959/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0259e-05 - accuracy: 1.0000
# Epoch 960/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 0.9932
# Epoch 961/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9932
# Epoch 962/1000
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0269 - accuracy: 0.9932
# Epoch 963/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1564 - accuracy: 0.9795
# Epoch 964/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9932
# Epoch 965/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 0.9863
# Epoch 966/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0934 - accuracy: 0.9863
# Epoch 967/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1067 - accuracy: 0.9863
# Epoch 968/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0672 - accuracy: 0.9863
# Epoch 969/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0555 - accuracy: 0.9863
# Epoch 970/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0804 - accuracy: 0.9863
# Epoch 971/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1244 - accuracy: 0.9795
# Epoch 972/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1322 - accuracy: 0.9863
# Epoch 973/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9932
# Epoch 974/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0646 - accuracy: 0.9863
# Epoch 975/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 976/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 0.9932
# Epoch 977/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 0.9863
# Epoch 978/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1234 - accuracy: 0.9795
# Epoch 979/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1554 - accuracy: 0.9863
# Epoch 980/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 1.8864e-05 - accuracy: 1.0000
# Epoch 981/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3743 - accuracy: 0.9795
# Epoch 982/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0053e-04 - accuracy: 1.0000
# Epoch 983/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9932
# Epoch 984/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9932
# Epoch 985/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 0.9932
# Epoch 986/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0523 - accuracy: 0.9863
# Epoch 987/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1645 - accuracy: 0.9863
# Epoch 988/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 0.9863
# Epoch 989/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0621 - accuracy: 0.9863
# Epoch 990/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9863
# Epoch 991/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1681 - accuracy: 0.9863
# Epoch 992/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 0.9932
# Epoch 993/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0968 - accuracy: 0.9726
# Epoch 994/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1406 - accuracy: 0.9863
# Epoch 995/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0469 - accuracy: 0.9932
# Epoch 996/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1884 - accuracy: 0.9658
# Epoch 997/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9863
# Epoch 998/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0333 - accuracy: 0.9932
# Epoch 999/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 0.9932
# Epoch 1000/1000
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0341 - accuracy: 0.9863

# %% [markdown]
# ## 10. Saving the Model

# %%
model.save('files/Chatbot.model')
# Out:
# INFO:tensorflow:Assets written to: files/Chatbot.model\assets

# %% [markdown]
# ## 11. Loading the Model

# %%
model = tf.keras.models.load_model('files/Chatbot.model')

# %% [markdown]
# ## 12. Unpickling Files and extracting Words, Classes, Data

# %%
import pickle
# Use Inspect functions
def Unpicklize(fileName:str):
    with open(f'files/pickleFiles/{fileName}', 'rb') as fp: return pickle.load(fp)

words = Unpicklize('words')
classes = Unpicklize('classes')
data = Unpicklize('data')

# %% [markdown]
# ## 13. Tokenize, Lemmatize, Clean, Predict, Respond

# %%
def richText(text):
    """tokenize -> lemmatize -> clean"""
    tokens = nltk.word_tokenize(text)
    return [lemmatizer.lemmatize(word) for word in tokens]



def wordsBag(text, vocabulary): 
    tokens = richText(text)
    bow = [0] * len(vocabulary)
    for tWord in tokens: 
        for idx, word in enumerate(vocabulary):
            if word == tWord: 
                bow[idx] = 1
    return np.array(bow)



def predict_Class(text, vocabulary, labels): 
    bow = wordsBag(text, vocabulary)
    result = model.predict(np.array([bow]))[0]
    thresh = 0.2
    y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]
    y_pred.sort(key=lambda x: x[1], reverse=True)

    return [labels[r[0]] for r in y_pred]



def get_Response(intents_list, intents_json):
    import random 
    intent = intents_list[0]
    list_of_intents = intents_json["intents"]
    for loi in list_of_intents: 
        if loi["intent"] == intent:
            result = random.choice(loi["responses"])
            break
    return result

# %% [markdown]
# ## 14. Method to Fetch City Data using OpenWeathermap API

# %%
from bs4 import BeautifulSoup
import requests

def get_City_Data(city:str = 'pune', data:str = 'all'):
	"""Get CITY Data
	================

	Parameters:
	-----------
	1. city:str - The city name for which data is requested
	2. data:str - Values('all', 'day-time', 'weather') returns city data according to this choice
	
	Returns:
	--------
	city data using OpenWeathermap API"""
	
	try:
		city = city.lower().replace(" ", "+") + " weather"
		headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3' }
		res = requests.get(f'https://www.google.com/search?q={city}&oq={city}&aqs=chrome.0.35i39l2j0l4j46j69i60.6128j1j7&sourceid=chrome&ie=UTF-8', headers=headers)

		soup = BeautifulSoup(res.text, 'html.parser')

		location, time, info, weather = map(
			lambda id: soup.select(id)[0].getText().strip(),
			('#wob_loc', '#wob_dts', '#wob_dc', '#wob_tm',)
		)

		if data == 'all': return f"City: {location} :: Date-Time: {time} :: Weather: {info}, {weather}°C"
		if data == 'time': return time
		if data == 'weather': return f"{info}, {weather}°C"
	
	except: return 'not found'

# %% [markdown]
# ## 15. Method to get Current Date-Time

# %%
from datetime import datetime

DA_Name = 'Jarvis'


def get_DateTime(data:str = 'date-time'):
    """Get Date Time
	================

	Parameters:
	-----------
	1. data:str - Values('date-time', 'accurate-date-time', 'time', 'accurate-time') returns data according to the choice
	
	Returns:
	--------
	date-time data using Date-Time API"""
    months = ('January', 'February', 'March', 'April')
    cDT = datetime.now()                                                # current date-time
    desiredData = {
        'date-time': f"{cDT:%B %d, 20%y, %H:%M}",
        'time': f"{cDT:%H:%M}",
        'accurate-time': f"{cDT:%H : %M : %S.%f}",
        'accurate-date-time': f"{cDT:%B %d, 20%y, %H:%M:%S.%f}"
    }

    return desiredData.get(data.strip(), 'unknown')

# %% [markdown]
# ## 16. Method to Scrap Dictionary

# %%
from PyDictionary import PyDictionary

# import google_images_search
import googlesearch as google

import webbrowser as wb
from urllib3 import *
from urllib import * 

from wikipedia import *
from pyjokes import *

import pandas as pd
import sys


dictionary = PyDictionary()
ActionDict = { 'mean' : dictionary.meaning, 'synonym' : dictionary.synonym, 'antonym' : dictionary.antonym, 'translate' : dictionary.translate }


def Access_Dictionary(WordList, Lang = 'en', Action = 'mean'):
    if isinstance(WordList, str): WordList = [WordList]

    try: return list(map(ActionDict.get(Action, 'mean'), WordList))
    except: return "Sorry! Some Error Occurred While Surfing Dictionary"

# %% [markdown]
# ## 17. Method to Surf Google

# %%
def SearchGoogle(Query = "Python"):
    try:
    # Website Versatility : Counting how many times Google Recommended each site while Querying
        WebsVers = {}
        
        for Website in google.search(Query, tld='com', lang='en', tbs='0', safe='off', num=2, start=0, stop=2, domains=None, pause=2.0, tpe='', country='', extra_params=None, user_agent=None):  #, Return)
            Website = Website[Website.find(':')+1:]
            
            while True:
                if Website[0] not in [':', '/']: break
                Website = Website[1:]
        
            Host = Website[: min(list(map(lambda x: x if x>=0 else 100, [Website.find(':'), Website.find('/')])))]
            WebsVers[Host] = WebsVers.get(Host, 0) + 1
        
        print(pd.DataFrame(zip(WebsVers.keys(), WebsVers.values()), columns = ["Site", "Count"]))


        Max, MaxSite = 0, ""
        for i,j in WebsVers.items():
            if j > Max: MaxSite, Max = i, j
        wb.open(MaxSite)

    except: print("An Error Occurred while Internet Surfing")

# %% [markdown]
# ## 18. Microphone Input, Speaker Output, Commands' Processing

# %%
import pyautogui as ag
import pyttsx3
import speech_recognition as sr
import pywhatkit as pwk
import webbrowser as wb

#region SETUP
DA_Name = 'Jarvis'
listener = sr.Recognizer()
engine  = pyttsx3.init()
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)
#endregion



def Listener(ackListening:bool = False):
    try:
        with sr.Microphone() as source:
            if ackListening: print(f"{DA_Name} :    I AM LISTENING.....")
            audio = listener.listen(source)
            command = listener.recognize_google(audio, language = 'en-US')
            command = ' '.join(command.lower().split())
            return command
    except: return "nothing heard"



def Speak(Str = "Hi, how can I help"):
    print(f"{DA_Name} : {Str} ......")
    engine.say(Str)
    # engine.runAndWait()
    return

# %% [markdown]
# ## 19. Refactor Model Response

# %%
# Computations needed for variables
def refactor_Model_Response(text:str, speakerMessage:str = ""):
    computations = { 
        '<currDateTime>' : get_DateTime('date-time' if speakerMessage.find('accurate') == -1 else 'accurate-date-time'),
        '<currTime>' : get_DateTime('time' if speakerMessage.find('accurate') == -1 else 'accurate-time'),
        '<Person>' : speakerMessage.split()[-1] if len(speakerMessage) else 'There',
        '<DA_Name>': DA_Name
    }
    
    for key, val in computations.items(): text = text.replace(key, val)

    return text

# %% [markdown]
# ## 20. Method to inspect Speaker command and perform action if desired

# %%
# Common commands
BasicCmds = { 'open', 'play', 'play song', 'play on youtube', 'connect to', 'press', 'take screenshot', 'search' }
deviceApps = { 'explorer', 'file explorer', 'cmd', 'command prompt', 'shell', 'powershell', 'wmplayer', 'windows media player', 'mspaint', 'paint', 'taskmgr', 'task manager', 'notepad', 'calc', 'calculator' }
websites = {
    'google': 'https://www.google.com',
    'instagram': 'https://www.instagram.com/'
}



def Open(app_site_Name:str):
    """Open App-Website
    ----------------
    Performs open action on app or website"""

    app_site_Name = app_site_Name.lower().strip()
    if app_site_Name in deviceApps:
        ag.hotkey('win', 's')
        ag.typewrite(app_site_Name)
        ag.press('enter')

    else: wb.open(websites.get(app_site_Name, 'https://www.google.com'))




def inspect_Speaker_Cmd(command:str):
    """Recognizes Type of Command
    -----------------------------"""

    command = command.lower().strip()

    # Dictionary Search ->  Word - Meaning - Synonym - Antonym
    if any([ "mean" in command, "synonym" in command, "antonym" in command ]):
        for phrase in ["mean by", "meaning of", "synonym of", "synonyms of", "antonym of", "antonyms of"]:
            if phrase in command:
                Speak(str(Access_Dictionary(command[command.find(phrase) + len(phrase) :].strip())))
                break
        else: Speak(str(Access_Dictionary(command.split()[-1])))


    # Fetching Weather Data for a City
    if pos := command.find('weather') != -1:
        
        if 'get' in command:
            command = command.split()
            city = ' '.join(command[command.index('get')+1 : command.index('weather')])
            Speak(f"Fetching {city} weather")
            return get_City_Data(city)
        
        if pos := command.find('of') != -1:
            city = command[pos+2:]
            Speak(f"Fetching {city} weather")
            return get_City_Data(city)
        
        return "not done"
    

    # If Command contains any of the Reserved Commands
    if any(cmd in command for cmd in BasicCmds):
        if pos := command.find('press') != -1:
            # Clean and extract keys
            keys = command[pos+5:].split()
            ag.hotkey(*keys)

        if pos := command.find('open') != -1:
            app_site_name = command[pos+4:]
            Speak(f"Opening {app_site_name}")
            Open(app_site_name)
               
        if pos := command.find('play song') != -1:
            songName = command[pos+9:]
            Speak(f"Playing song {songName}")
            pwk.playonyt(songName)
        
        if pos := command.find('play') != -1:
            songName = command[pos+4:]
            Speak(f"Playing {songName}")
            pwk.playonyt(songName)
        
        if pos:= command.find('search') != -1:
            query = command[pos+6:]
            Speak(f"Searching Google for {query}")
            SearchGoogle(query)

        return "not done"



    #except: print("Error")

# %% [markdown]
# ## 21. Final Chatbot interface for User with Digital Assistant

# %%
# Chatbot
def Chatbot(DA_Name = 'Jarvis'):
    # try:
    print('Hi, How can I help!')
    Speak()
    try:
        while True:
            # command = Listener(True)
            # if command == 'stop': break
            # while command == 'nothing heard':
            #     command = Listener(True)
            command = input()
            print(f"You: {command}")
            
            # command = inspect_Speaker_Cmd(command)

            if command != 'not done':
                intents = predict_Class(command, words, classes)
                result = get_Response(intents, data)
                result = refactor_Model_Response(result, command)
                Speak(result)
            
    except KeyboardInterrupt: return
    # except Exception: return 'Sorry! Something Went Wrong'

# %% [markdown]
# ## 22. Execution

# %%
Chatbot()
# Out:
# Hi, How can I help!
# You:
# Jarvis : OK, sorry to disturb you ......
# You:
# Jarvis : Fine, sorry to disturb you ......
# You:
# Jarvis : OK, sorry to disturb you ......
